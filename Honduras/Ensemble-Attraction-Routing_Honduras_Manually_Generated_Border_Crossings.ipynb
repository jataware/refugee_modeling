# %% [markdown]
# # Generate Estimated Refugee Numbers and Routes

# %% [markdown]
# ## 1. Data Collection

# %%
import json
import pandas as pd
from fuzzywuzzy import process
from sklearn.preprocessing import MinMaxScaler
from statsmodels.iolib.smpickle import load_pickle
import numpy as np

# %% [markdown]
# ### Parameters
# Set these values as parameters for the model.
# Set conflict city and number of cities for conflict and camp countries

# %%
conflict_country= "Honduras"
percent_of_pop_leaving=.10
flight_mode="driving"
conflict_start=2021
excluded_countries=[]
added_countries=[]
number_conflict_cities=20
number_camp_cities=10

# %%
conflict_start=conflict_start-1

# %% [markdown]
# ### Helper functions

# %%
# Helper Encoder for json
class NpEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, np.integer):
            return int(obj)
        if isinstance(obj, np.floating):
            return float(obj)
        if isinstance(obj, np.ndarray):
            return obj.tolist()
        return super(NpEncoder, self).default(obj)

# %% [markdown]
# ## 2. Collect relevant data

# %% [markdown]
# read in country border data

# %%
country_border = open('../refugee_data/country_border_data.json')
countries_that_border = json.load(country_border)

# %% [markdown]
# get a list of touching countries

# %%
touching_list=[]
touching_list=countries_that_border[conflict_country]
touching_list
# Out:
# ['El Salvador', 'Guatemala', 'Nicaragua']

# %% [markdown]
# remove any countries that are to be excluded.

# %%
indexed_list={}
for i,c in enumerate(touching_list):
    indexed_list[i]=c
    
for i,ex in enumerate(excluded_countries):
    country,value, ind=process.extractOne(ex, indexed_list)
    if value>89:
        touching_list.pop(ind)
    print(country, value, ind)
    print(touching_list)

# %% [markdown]
# add any countries we need to

# %%
for country_v in added_countries:
    touching_list.append(country_v)
touching_list
# Out:
# ['El Salvador', 'Guatemala', 'Nicaragua']

# %% [markdown]
# create a dataframe to build upon.

# %%
touching_df = pd.DataFrame (touching_list, columns = ['bording_countries'])
touching_df['conflict']=conflict_country

# %% [markdown]
# read in historic_pop

# %%
historic_pop=pd.read_csv('../refugee_data/historic_pop.csv')

# %% [markdown]
# Get historic populations from year before conflict

# %%
options=historic_pop["Country Name"]
touching_df['historic_pop']=None
historic_pop_cols=historic_pop.columns

indexed_col={}
for i,c in enumerate(historic_pop_cols):
    indexed_col[i]=c

column,ratio_year, year_column_idx = process.extractOne(str(conflict_start), indexed_col)


for kk ,border in touching_df.iterrows():
    country,ratio,ind =process.extractOne(border["bording_countries"], options)
    touching_df.loc[kk,"historic_pop"]=historic_pop.at[ind,column]

# %% [markdown]
# Get historic population of conflict country

# %%
country,ratio,ind =process.extractOne(conflict_country, options)
conflict_country_historic_pop=int(historic_pop.at[ind,column])
conflict_country_historic_pop
# Out:
# 9904608

# %% [markdown]
# read in historic gdp per cap data. Get data from historic gdp per cap given the year.

# %%
gdp_per_cap_historic=pd.read_csv("../refugee_data/gdp_per_cap.csv")

# %%
options=gdp_per_cap_historic["Country Name"]
touching_df['historic_gdp_per_cap']=None

historic_gdp_cols=gdp_per_cap_historic.columns
indexed_gdp_col={}
for i,c in enumerate(historic_gdp_cols):
    indexed_gdp_col[i]=c

    
column,ratio_year, year_column_idx = process.extractOne(str(conflict_start), indexed_gdp_col)

for kk ,border in touching_df.iterrows():
    country,ratio,ind =process.extractOne(border["bording_countries"], options)
    touching_df.loc[kk,"historic_gdp_per_cap"]=gdp_per_cap_historic.at[ind,column]

# %% [markdown]
# calculate historic gdp for later use if needed

# %%
touching_df['calculated_historic_gdp']=None
for kk ,row in touching_df.iterrows():
    try:
        touching_df.loc[kk,"calculated_historic_gdp"]=int(row['historic_pop'])*float(row['historic_gdp_per_cap'])
    except Exception as e:
        print(e, f'GDP per cap for {row["bording_countries"]} data was {row["historic_gdp_per_cap"]}' )

# %% [markdown]
# read in V-Dem data and subset the dataset to only enclude columns we care about

# %%
Dem=pd.read_csv("../refugee_data/country_dem.csv")
columnList=["country_name","year","v2xeg_eqdr","v2x_libdem"]
country_dem=Dem[columnList]

# %% [markdown]
# collect liberal democracy and access to justic for women data for each country given conflict year

# %%
touching_df["v2x_libdem"]=None
touching_df["v2xeg_eqdr"]=None

options=country_dem['country_name'].unique()

for kk ,row in touching_df.iterrows():
    country,ratio =process.extractOne(row["bording_countries"], options)
    lib=country_dem.loc[(country_dem["country_name"]==country) & (country_dem["year"]==int(conflict_start))]['v2x_libdem']
    eqdr=country_dem.loc[(country_dem["country_name"]==country) & (country_dem["year"]==int(conflict_start))]['v2xeg_eqdr']
    touching_df.loc[kk,"v2xeg_eqdr"]=eqdr.to_list()[0]
    touching_df.loc[kk,"v2x_libdem"]=lib.to_list()[0]

# %% [markdown]
# read in historic gdp from world bank not calculated manually.

# %%
historic_GDP=pd.read_csv('../refugee_data/GDP_historic.csv')

# %% [markdown]
# Get data from historic gdp per cap given the year.

# %%
options=historic_GDP["Country Name"]
touching_df['historic_GDP']=None
historic_GDP_cols=historic_GDP.columns
indexed_GDP_col={}
for i,c in enumerate(historic_GDP_cols):
    indexed_GDP_col[i]=c

    
column,ratio_year, year_column_idx = process.extractOne(str(conflict_start), indexed_GDP_col)

for kk ,border in touching_df.iterrows():
    country,ratio,ind =process.extractOne(border["bording_countries"], options)
    touching_df.loc[kk,"historic_GDP"]=historic_GDP.at[ind,column]

# %%
touching_df
# Out:
#   bording_countries  conflict historic_pop historic_gdp_per_cap  \
# 0       El Salvador  Honduras      6486201     3798.63652082321
# 1         Guatemala  Honduras     16858333     4603.33961670975
# 2         Nicaragua  Honduras      6624554     1905.26115155921
#
#   calculated_historic_gdp v2x_libdem v2xeg_eqdr        historic_GDP
# 0      24638720000.000027       0.37      0.273       24638720000.0
# 1      77604632170.585327      0.394       0.21  77604632170.585297
# 2      12621505382.606171      0.058      0.428  12621505382.606199

# %% [markdown]
# Normalize the columns we will run the model on that are not already an index. For our current model that is only historic_GDP.

# %%
cols_to_scale = ['historic_GDP']
touching_df=touching_df.rename(columns={'bording_countries':'country'})

# %%
scaler = MinMaxScaler()
for col in cols_to_scale:
    print(col)
    normed = pd.DataFrame()
    
    for y, x in touching_df.groupby('conflict'):
        print(y,x)
        norm_ = [i[0] for i in scaler.fit_transform(x[col].values.reshape(-1,1))]
        countries = x['country']
        conflict_ = x['conflict']
        res = pd.DataFrame(tuple(zip(countries,conflict_,norm_)), columns=['country','conflict',f"{col}_norm"])
        normed = normed.append(res)
    normalized_data = pd.merge(touching_df, normed, left_on=['country','conflict'], right_on=['country','conflict'], how='right')
# Out:
# historic_GDP
# Honduras        country  conflict historic_pop historic_gdp_per_cap  \
# 0  El Salvador  Honduras      6486201     3798.63652082321
# 1    Guatemala  Honduras     16858333     4603.33961670975
# 2    Nicaragua  Honduras      6624554     1905.26115155921
#
#   calculated_historic_gdp v2x_libdem v2xeg_eqdr        historic_GDP
# 0      24638720000.000027       0.37      0.273       24638720000.0
# 1      77604632170.585327      0.394       0.21  77604632170.585297
# 2      12621505382.606171      0.058      0.428  12621505382.606199
# <ipython-input-787-5d4ebbd7a47f>:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   normed = normed.append(res)

# %%
normalized_data
# Out:
#        country  conflict historic_pop historic_gdp_per_cap  \
# 0  El Salvador  Honduras      6486201     3798.63652082321
# 1    Guatemala  Honduras     16858333     4603.33961670975
# 2    Nicaragua  Honduras      6624554     1905.26115155921
#
#   calculated_historic_gdp v2x_libdem v2xeg_eqdr        historic_GDP  \
# 0      24638720000.000027       0.37      0.273       24638720000.0
# 1      77604632170.585327      0.394       0.21  77604632170.585297
# 2      12621505382.606171      0.058      0.428  12621505382.606199
#
#    historic_GDP_norm
# 0           0.184928
# 1           1.000000
# 2           0.000000

# %% [markdown]
# ## 3. Modeling
# Load the prebuild model

# %%
new_results = load_pickle("../refugee_model_results.pickle")

# %% [markdown]
# set independant variables

# %%
features_cols = [
                    'historic_GDP_norm', 
                    'v2x_libdem',
]
features_normalized = normalized_data[features_cols]
normalized_data[['country',"conflict"]+features_cols]
# Out:
#        country  conflict  historic_GDP_norm v2x_libdem
# 0  El Salvador  Honduras           0.184928       0.37
# 1    Guatemala  Honduras           1.000000      0.394
# 2    Nicaragua  Honduras           0.000000      0.058

# %% [markdown]
# Currently if a country does not have data for a column we are dropping that country. If you need to not drop a country you need to fill in the missing data manually or some other method.

# %%
normalized_data=normalized_data.dropna()

# %% [markdown]
# Select only features that are needed and use the model to predict

# %%
features_to_predict=normalized_data[features_cols]
shares = new_results.predict(features_to_predict)
normalized_data['predicted_shares'] = shares

# %% [markdown]
# save results to a csv file for next step.

# %%
border_countries_results = normalized_data[['country',"conflict","historic_pop","historic_GDP_norm","v2x_libdem",'predicted_shares']]
border_countries_results.to_csv(f'outputs/{conflict_country}_{flight_mode}_output_results.csv',index=False)

# %%
border_countries_results
# Out:
#        country  conflict historic_pop  historic_GDP_norm v2x_libdem  \
# 0  El Salvador  Honduras      6486201           0.184928       0.37
# 1    Guatemala  Honduras     16858333           1.000000      0.394
# 2    Nicaragua  Honduras      6624554           0.000000      0.058
#
#   predicted_shares
# 0         0.192316
# 1         0.393016
# 2         0.023352

# %% [markdown]
# # 4. Find Border crossing for haven countries

# %% [markdown]
# This will look up boarder crossings from a dataset we found on wikipeadia. If you don't want to collect border crossing manuall use this code.

# %%
with open('../refugee_data/border_crossing_geopoints.json') as json_file:
    border_geo = json.load(json_file)

# %%
border_geo["Honduras"]
# Out:
# [{'crossing_name': 'Virginia', 'latitude': '14.0167', 'longitude': '-88.5667'}]

# %%
array_of_crossings_df = pd.DataFrame(columns=['country','crossing_name','latitude','longitude'])
array_of_crossings_df
#haven countries
for kk,border in border_countries_results.iterrows():
    print(border['country'])
    for crossing in border_geo[border['country']]:
        array_of_crossings_df.loc[len(array_of_crossings_df.index)] = [border['country'],crossing['crossing_name'], crossing['latitude'],crossing['longitude']]
# conflict country
for crossing in border_geo[conflict_country]:
    array_of_crossings_df.loc[len(array_of_crossings_df.index)] = [conflict_country,crossing['crossing_name'], crossing['latitude'],crossing['longitude']]
# Out:
# El Salvador
# Guatemala
# Nicaragua

# %%
array_of_crossings_df
# Out:
#         country          crossing_name      latitude      longitude
# 0   El Salvador                 Citalá  14.366666666  -89.216666666
# 1   El Salvador            San Lorenzo  14.033333333  -89.783333333
# 2     Guatemala             Esquipulas  14.616666666          -89.2
# 3     Guatemala      Melchor de Mencos   17.06666667         -89.15
# 4     Guatemala             La Mesilla  15.616666666  -91.983333333
# 5     Guatemala                 Ayutla  14.683333333  -92.133333333
# 6     Nicaragua              San Ramón  12.916666666  -85.833333333
# 7     Nicaragua            El Castillo   11.01777778   -84.40111111
# 8     Nicaragua                 Waspam  14.740833333  -83.971944444
# 9     Nicaragua            El Castillo   11.01777778   -84.40111111
# 10    Nicaragua  San Juan de Nicaragua  10.946666666  -83.735833333
# 11     Honduras               Virginia       14.0167       -88.5667

# %% [markdown]
# If you want to upload manually generated border crossing location do that here.

# %%
array_of_crossings_df=pd.read_csv('../refugee_data/manual_honduras_crossings.csv')

# %%
array_of_crossings_df
# Out:
#        country       crossing_name  longitude   latitude
# 0    Guatemala             Corinto -88.372008  15.595600
# 1    Guatemala       Aldea Caparja -89.226200  14.857400
# 2    Guatemala     Aguas Calientes -89.283170  14.531062
# 3  El Salvador              Citala -89.209463  14.371879
# 4  El Salvador          El Amatilo -87.773412  13.591830
# 5    Nicaragua    Aduana El Espino -86.724237  13.445553
# 6    Nicaragua  Frontera Las Manos -86.570047  13.792918

# %% [markdown]
# ## 4. Find Largest Cities in Conflict and Destination Countries

# %%
from functools import partial
import geopandas as gpd
import pandas as pd
import math
import numpy as np
import shapely
from shapely.geometry import Point
import googlemaps
import pgeocode
import pyproj
from fuzzywuzzy import process

# %% [markdown]
# Read in cities data with all cities with population over 15000 people. Then subset columns

# %%
CITY_FILE = "../refugee_data/cities15000.txt"
city_df = pd.read_csv(
    CITY_FILE, 
    sep="\t", 
    header=0,
    names=[
         "geonameid", 
 "name", 
 "asciiname", 
 "alternatenames", 
 "latitude", 
 "longitude", 
 "feature class", 
 "feature code", 
 "country code", 
 "cc2", 
 "admin1 code", 
 "admin2 code", 
 "admin3 code", 
 "admin4 code", 
 "population", 
 "elevation", 
 "dem", 
 "timezone", 
 "modification date", 

    ]
)
#subset_cols=["name","latitude","longitude", "country code", "population"]
#city_df=city_df[subset_cols]

# %%
#city_df[city_df["country code"]=="RO"].sort_values("population",ascending=False).head(10)

# %%
subset_cols=["name","latitude","longitude", "country code", "population"]
city_df=city_df[subset_cols]

# %% [markdown]
# Read in the results from the collect_to_normalized notebook that we saved in the output folder

# %%
border_countries_results
# Out:
#        country  conflict historic_pop  historic_GDP_norm v2x_libdem  \
# 0  El Salvador  Honduras      6486201           0.184928       0.37
# 1    Guatemala  Honduras     16858333           1.000000      0.394
# 2    Nicaragua  Honduras      6624554           0.000000      0.058
#
#   predicted_shares
# 0         0.192316
# 1         0.393016
# 2         0.023352

# %% [markdown]
# Read in county codes data so we merge the two data sources

# %%
codes=  pd.read_csv("../refugee_data/wikipedia-iso-country-codes.csv")

# %%
codes.head()
# Out:
#   English short name lower case Alpha-2 code Alpha-3 code  Numeric code  \
# 0                   Afghanistan           AF          AFG             4
# 1                 Åland Islands           AX          ALA           248
# 2                       Albania           AL          ALB             8
# 3                       Algeria           DZ          DZA            12
# 4                American Samoa           AS          ASM            16
#
#       ISO 3166-2
# 0  ISO 3166-2:AF
# 1  ISO 3166-2:AX
# 2  ISO 3166-2:AL
# 3  ISO 3166-2:DZ
# 4  ISO 3166-2:AS

# %% [markdown]
# Add a column for country_code to our border_countries dataframe

# %%
options=codes["English short name lower case"]

for kk ,border in border_countries_results.iterrows():
    country,ratio,ind =process.extractOne(border["country"], options)
    border_countries_results.loc[kk,"country_code"]=codes.at[ind,"Alpha-2 code"]
# Out:
# <ipython-input-808-c64a94700c7f>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   border_countries_results.loc[kk,"country_code"]=codes.at[ind,"Alpha-2 code"]

# %% [markdown]
# We need the code for the conflict country as well.

# %%
country,ratio,ind =process.extractOne(border_countries_results["conflict"][0], options)
conflict_code=codes.at[ind,"Alpha-2 code"]
conflict_code
# Out:
# 'HN'

# %% [markdown]
# Collect largest n cities in conflict country. This can be changed by the parameter number_conflict_cities. We also will add two column for country and location_type for future use.

# %%
filtered_df=city_df[city_df["country code"]==conflict_code]
filtered_df=filtered_df.sort_values(by="population", ascending=False)
largest_conflict_cities=filtered_df[0:number_conflict_cities]
largest_conflict_cities['country']=conflict_country
largest_conflict_cities['location_type']="conflict_zone"
largest_conflict_cities
# Out:
# <ipython-input-810-cf4d2a57b580>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   largest_conflict_cities['country']=conflict_country
# <ipython-input-810-cf4d2a57b580>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   largest_conflict_cities['location_type']="conflict_zone"
#                      name  latitude  longitude country code  population  \
# 9716          Tegucigalpa  14.08180  -87.20681           HN      850848
# 9720       San Pedro Sula  15.50417  -88.02500           HN      489466
# 9734              Choloma  15.61444  -87.95302           HN      139100
# 9726             La Ceiba  15.75971  -86.78221           HN      130218
# 9728          El Progreso  15.40000  -87.80000           HN      100810
# 9733     Ciudad Choluteca  13.30028  -87.19083           HN       75872
# 9731            Comayagua  14.45139  -87.63750           HN       58784
# 9711        Puerto Cortez  15.82562  -87.92968           HN       48013
# 9725              La Lima  15.43333  -87.91667           HN       45955
# 9730                Danlí  14.03333  -86.58333           HN       44799
# 9717         Siguatepeque  14.59691  -87.83102           HN       43141
# 9727            Juticalpa  14.66667  -86.21944           HN       33686
# 9713           Villanueva  15.31476  -87.99383           HN       31571
# 9714                Tocoa  15.68333  -86.00000           HN       30785
# 9715                 Tela  15.77425  -87.46731           HN       29325
# 9718  Santa Rosa de Copán  14.76667  -88.77917           HN       27753
# 9723            Olanchito  15.48131  -86.57415           HN       25969
# 9721          San Lorenzo  13.42417  -87.44722           HN       22289
# 9732             Cofradía  15.40000  -88.15000           HN       20353
# 9729           El Paraíso  13.86667  -86.55000           HN       18779
#
#        country  location_type
# 9716  Honduras  conflict_zone
# 9720  Honduras  conflict_zone
# 9734  Honduras  conflict_zone
# 9726  Honduras  conflict_zone
# 9728  Honduras  conflict_zone
# 9733  Honduras  conflict_zone
# 9731  Honduras  conflict_zone
# 9711  Honduras  conflict_zone
# 9725  Honduras  conflict_zone
# 9730  Honduras  conflict_zone
# 9717  Honduras  conflict_zone
# 9727  Honduras  conflict_zone
# 9713  Honduras  conflict_zone
# 9714  Honduras  conflict_zone
# 9715  Honduras  conflict_zone
# 9718  Honduras  conflict_zone
# 9723  Honduras  conflict_zone
# 9721  Honduras  conflict_zone
# 9732  Honduras  conflict_zone
# 9729  Honduras  conflict_zone

# %% [markdown]
# Do the same for largest camp cities for each bordering country

# %%
largest_camp_cities = pd.DataFrame(columns = city_df.columns)

for kk ,border in border_countries_results.iterrows():
    filtered_df=city_df[city_df["country code"]==border['country_code']]
    filtered_df['country']=border['country']
    filtered_df=filtered_df.sort_values(by="population", ascending=False)
    largest_camp_cities_f=filtered_df[0:number_camp_cities]
    largest_camp_cities=largest_camp_cities.append(largest_camp_cities_f)
largest_camp_cities["location_type"]='camp'
largest_camp_cities
# Out:
# <ipython-input-811-d347ca4045ff>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['country']=border['country']
# <ipython-input-811-d347ca4045ff>:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   largest_camp_cities=largest_camp_cities.append(largest_camp_cities_f)
# <ipython-input-811-d347ca4045ff>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['country']=border['country']
# <ipython-input-811-d347ca4045ff>:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   largest_camp_cities=largest_camp_cities.append(largest_camp_cities_f)
# <ipython-input-811-d347ca4045ff>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['country']=border['country']
# <ipython-input-811-d347ca4045ff>:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   largest_camp_cities=largest_camp_cities.append(largest_camp_cities_f)
#                         name  latitude longitude country code population  \
# 20274           San Salvador  13.68935 -89.18718           SV     525990
# 20267              Soyapango  13.71024 -89.13989           SV     329708
# 20273              Santa Ana  13.99417 -89.55972           SV     176661
# 20276             San Miguel  13.48333 -88.18333           SV     161880
# 20284              Mejicanos  13.72397   -89.188           SV     160317
# 20282            Santa Tecla  13.67694 -89.27972           SV     124694
# 20295                  Apopa  13.80722 -89.17917           SV     112158
# 20289                Delgado  13.72171 -89.16874           SV      71594
# 20269              Sonsonate  13.71889 -89.72417           SV      59468
# 20278             San Marcos  13.66108 -89.18252           SV      54615
# 9678          Guatemala City  14.64072 -90.51327           GT     994938
# 9654                   Mixco  14.63077 -90.60711           GT     473080
# 9611             Villa Nueva  14.52512 -90.58544           GT     406830
# 9642                  Petapa  14.50189 -90.56196           GT     141455
# 9628   San Juan Sacatepéquez  14.71889 -90.64417           GT     136886
# 9637          Quetzaltenango  14.83472 -91.51806           GT     132230
# 9612           Villa Canales  14.48285 -90.53425           GT     122194
# 9667               Escuintla   14.3009 -90.78581           GT     103165
# 9681               Chinautla  14.70289 -90.49983           GT      97172
# 9682           Chimaltenango  14.66111 -90.81944           GT      82370
# 16684                Managua  12.13282  -86.2504           NI     973087
# 16685                   León  12.43787 -86.87804           NI     144538
# 16682                 Masaya  11.97444 -86.09417           NI     130113
# 16697             Chinandega  12.62937 -87.13105           NI     126387
# 16681              Matagalpa  12.92559 -85.91747           NI     109089
# 16692                 Estelí  13.09185 -86.35384           NI      96422
# 16691                Granada  11.92988 -85.95602           NI      89409
# 16689               Jinotega  13.09103 -86.00234           NI      55000
# 16693               El Viejo  12.66348 -87.16663           NI      53504
# 16678           Nueva Guinea  11.68758 -84.45616           NI      52929
#
#            country location_type
# 20274  El Salvador          camp
# 20267  El Salvador          camp
# 20273  El Salvador          camp
# 20276  El Salvador          camp
# 20284  El Salvador          camp
# 20282  El Salvador          camp
# 20295  El Salvador          camp
# 20289  El Salvador          camp
# 20269  El Salvador          camp
# 20278  El Salvador          camp
# 9678     Guatemala          camp
# 9654     Guatemala          camp
# 9611     Guatemala          camp
# 9642     Guatemala          camp
# 9628     Guatemala          camp
# 9637     Guatemala          camp
# 9612     Guatemala          camp
# 9667     Guatemala          camp
# 9681     Guatemala          camp
# 9682     Guatemala          camp
# 16684    Nicaragua          camp
# 16685    Nicaragua          camp
# 16682    Nicaragua          camp
# 16697    Nicaragua          camp
# 16681    Nicaragua          camp
# 16692    Nicaragua          camp
# 16691    Nicaragua          camp
# 16689    Nicaragua          camp
# 16693    Nicaragua          camp
# 16678    Nicaragua          camp

# %% [markdown]
# Merge and update column names

# %%
for kk ,conflict_city in largest_conflict_cities.iterrows():
    largest_camp_cities=largest_camp_cities.append(conflict_city)
locations=largest_camp_cities.rename(columns={"name":"#name"})
# Out:
# <ipython-input-812-def009a92a7e>:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   largest_camp_cities=largest_camp_cities.append(conflict_city)
# <ipython-input-812-def009a92a7e>:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   largest_camp_cities=largest_camp_cities.append(conflict_city)
# <ipython-input-812-def009a92a7e>:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   largest_camp_cities=largest_camp_cities.append(conflict_city)
# <ipython-input-812-def009a92a7e>:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   largest_camp_cities=largest_camp_cities.append(conflict_city)
# <ipython-input-812-def009a92a7e>:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   largest_camp_cities=largest_camp_cities.append(conflict_city)
# <ipython-input-812-def009a92a7e>:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   largest_camp_cities=largest_camp_cities.append(conflict_city)
# <ipython-input-812-def009a92a7e>:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   largest_camp_cities=largest_camp_cities.append(conflict_city)
# <ipython-input-812-def009a92a7e>:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   largest_camp_cities=largest_camp_cities.append(conflict_city)
# <ipython-input-812-def009a92a7e>:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   largest_camp_cities=largest_camp_cities.append(conflict_city)
# <ipython-input-812-def009a92a7e>:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   largest_camp_cities=largest_camp_cities.append(conflict_city)
# <ipython-input-812-def009a92a7e>:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   largest_camp_cities=largest_camp_cities.append(conflict_city)
# <ipython-input-812-def009a92a7e>:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   largest_camp_cities=largest_camp_cities.append(conflict_city)
# <ipython-input-812-def009a92a7e>:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   largest_camp_cities=largest_camp_cities.append(conflict_city)
# <ipython-input-812-def009a92a7e>:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   largest_camp_cities=largest_camp_cities.append(conflict_city)
# <ipython-input-812-def009a92a7e>:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   largest_camp_cities=largest_camp_cities.append(conflict_city)
# <ipython-input-812-def009a92a7e>:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   largest_camp_cities=largest_camp_cities.append(conflict_city)
# <ipython-input-812-def009a92a7e>:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   largest_camp_cities=largest_camp_cities.append(conflict_city)
# <ipython-input-812-def009a92a7e>:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   largest_camp_cities=largest_camp_cities.append(conflict_city)
# <ipython-input-812-def009a92a7e>:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   largest_camp_cities=largest_camp_cities.append(conflict_city)
# <ipython-input-812-def009a92a7e>:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   largest_camp_cities=largest_camp_cities.append(conflict_city)

# %%
locations.head(50)
# Out:
#                        #name  latitude longitude country code population  \
# 20274           San Salvador  13.68935 -89.18718           SV     525990
# 20267              Soyapango  13.71024 -89.13989           SV     329708
# 20273              Santa Ana  13.99417 -89.55972           SV     176661
# 20276             San Miguel  13.48333 -88.18333           SV     161880
# 20284              Mejicanos  13.72397   -89.188           SV     160317
# 20282            Santa Tecla  13.67694 -89.27972           SV     124694
# 20295                  Apopa  13.80722 -89.17917           SV     112158
# 20289                Delgado  13.72171 -89.16874           SV      71594
# 20269              Sonsonate  13.71889 -89.72417           SV      59468
# 20278             San Marcos  13.66108 -89.18252           SV      54615
# 9678          Guatemala City  14.64072 -90.51327           GT     994938
# 9654                   Mixco  14.63077 -90.60711           GT     473080
# 9611             Villa Nueva  14.52512 -90.58544           GT     406830
# 9642                  Petapa  14.50189 -90.56196           GT     141455
# 9628   San Juan Sacatepéquez  14.71889 -90.64417           GT     136886
# 9637          Quetzaltenango  14.83472 -91.51806           GT     132230
# 9612           Villa Canales  14.48285 -90.53425           GT     122194
# 9667               Escuintla   14.3009 -90.78581           GT     103165
# 9681               Chinautla  14.70289 -90.49983           GT      97172
# 9682           Chimaltenango  14.66111 -90.81944           GT      82370
# 16684                Managua  12.13282  -86.2504           NI     973087
# 16685                   León  12.43787 -86.87804           NI     144538
# 16682                 Masaya  11.97444 -86.09417           NI     130113
# 16697             Chinandega  12.62937 -87.13105           NI     126387
# 16681              Matagalpa  12.92559 -85.91747           NI     109089
# 16692                 Estelí  13.09185 -86.35384           NI      96422
# 16691                Granada  11.92988 -85.95602           NI      89409
# 16689               Jinotega  13.09103 -86.00234           NI      55000
# 16693               El Viejo  12.66348 -87.16663           NI      53504
# 16678           Nueva Guinea  11.68758 -84.45616           NI      52929
# 9716             Tegucigalpa   14.0818 -87.20681           HN     850848
# 9720          San Pedro Sula  15.50417   -88.025           HN     489466
# 9734                 Choloma  15.61444 -87.95302           HN     139100
# 9726                La Ceiba  15.75971 -86.78221           HN     130218
# 9728             El Progreso      15.4     -87.8           HN     100810
# 9733        Ciudad Choluteca  13.30028 -87.19083           HN      75872
# 9731               Comayagua  14.45139  -87.6375           HN      58784
# 9711           Puerto Cortez  15.82562 -87.92968           HN      48013
# 9725                 La Lima  15.43333 -87.91667           HN      45955
# 9730                   Danlí  14.03333 -86.58333           HN      44799
# 9717            Siguatepeque  14.59691 -87.83102           HN      43141
# 9727               Juticalpa  14.66667 -86.21944           HN      33686
# 9713              Villanueva  15.31476 -87.99383           HN      31571
# 9714                   Tocoa  15.68333     -86.0           HN      30785
# 9715                    Tela  15.77425 -87.46731           HN      29325
# 9718     Santa Rosa de Copán  14.76667 -88.77917           HN      27753
# 9723               Olanchito  15.48131 -86.57415           HN      25969
# 9721             San Lorenzo  13.42417 -87.44722           HN      22289
# 9732                Cofradía      15.4    -88.15           HN      20353
# 9729              El Paraíso  13.86667    -86.55           HN      18779
#
#            country  location_type
# 20274  El Salvador           camp
# 20267  El Salvador           camp
# 20273  El Salvador           camp
# 20276  El Salvador           camp
# 20284  El Salvador           camp
# 20282  El Salvador           camp
# 20295  El Salvador           camp
# 20289  El Salvador           camp
# 20269  El Salvador           camp
# 20278  El Salvador           camp
# 9678     Guatemala           camp
# 9654     Guatemala           camp
# 9611     Guatemala           camp
# 9642     Guatemala           camp
# 9628     Guatemala           camp
# 9637     Guatemala           camp
# 9612     Guatemala           camp
# 9667     Guatemala           camp
# 9681     Guatemala           camp
# 9682     Guatemala           camp
# 16684    Nicaragua           camp
# 16685    Nicaragua           camp
# 16682    Nicaragua           camp
# 16697    Nicaragua           camp
# 16681    Nicaragua           camp
# 16692    Nicaragua           camp
# 16691    Nicaragua           camp
# 16689    Nicaragua           camp
# 16693    Nicaragua           camp
# 16678    Nicaragua           camp
# 9716      Honduras  conflict_zone
# 9720      Honduras  conflict_zone
# 9734      Honduras  conflict_zone
# 9726      Honduras  conflict_zone
# 9728      Honduras  conflict_zone
# 9733      Honduras  conflict_zone
# 9731      Honduras  conflict_zone
# 9711      Honduras  conflict_zone
# 9725      Honduras  conflict_zone
# 9730      Honduras  conflict_zone
# 9717      Honduras  conflict_zone
# 9727      Honduras  conflict_zone
# 9713      Honduras  conflict_zone
# 9714      Honduras  conflict_zone
# 9715      Honduras  conflict_zone
# 9718      Honduras  conflict_zone
# 9723      Honduras  conflict_zone
# 9721      Honduras  conflict_zone
# 9732      Honduras  conflict_zone
# 9729      Honduras  conflict_zone

# %%
city_df
# Out:
#                       name  latitude  longitude country code  population
# 0         Andorra la Vella  42.50779    1.52109           AD       20430
# 1       Umm Al Quwain City  25.56473   55.55517           AE       62747
# 2      Ras Al Khaimah City  25.78953   55.94320           AE      351943
# 3               Zayed City  23.65416   53.70522           AE       63482
# 4             Khawr Fakkān  25.33132   56.34199           AE       40677
# ...                    ...       ...        ...          ...         ...
# 25688             Bulawayo -20.15000   28.58333           ZW      699385
# 25689              Bindura -17.30192   31.33056           ZW       37423
# 25690           Beitbridge -22.21667   30.00000           ZW       26459
# 25691              Epworth -17.89000   31.14750           ZW      123250
# 25692          Chitungwiza -18.01274   31.07555           ZW      340360
#
# [25693 rows x 5 columns]

# %% [markdown]
# save to inputs folder with unique file name

# %%
locations.to_csv(f'inputs/{conflict_country}_{flight_mode}_locations.csv',index=False)

# %% [markdown]
# ## 5.  Route Generation

# %%
import json
import time
import requests

# google libraries
import googlemaps
import polyline

# mapping and shape utils
import folium
from folium import plugins

# data processing
import pandas as pd
import geopandas as gpd

import math

# %% [markdown]
# First, you need to enable the Google Directions API.

# %%
gmaps = googlemaps.Client(key='AIzaSyAPHPIx3pHfUVoCYZRVaZYy2l5WRowVitA')

# %% [markdown]
# Add custom basemaps to folium

# %%
basemaps = {
    'Google Maps': folium.TileLayer(
        tiles = 'https://mt1.google.com/vt/lyrs=m&x={x}&y={y}&z={z}',
        attr = 'Google',
        name = 'Google Maps',
        overlay = True,
        control = True
    ),
    'Google Satellite': folium.TileLayer(
        tiles = 'https://mt1.google.com/vt/lyrs=s&x={x}&y={y}&z={z}',
        attr = 'Google',
        name = 'Google Satellite',
        overlay = True,
        control = True
    ),
    'Google Terrain': folium.TileLayer(
        tiles = 'https://mt1.google.com/vt/lyrs=p&x={x}&y={y}&z={z}',
        attr = 'Google',
        name = 'Google Terrain',
        overlay = True,
        control = True
    ),
    'Google Satellite Hybrid': folium.TileLayer(
        tiles = 'https://mt1.google.com/vt/lyrs=y&x={x}&y={y}&z={z}',
        attr = 'Google',
        name = 'Google Satellite',
        overlay = True,
        control = True
    ),
    'Esri Satellite': folium.TileLayer(
        tiles = 'https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}',
        attr = 'Esri',
        name = 'Esri Satellite',
        overlay = True,
        control = True
    )
}

# %% [markdown]
#  use locations generated above

# %%
locations.head()
# Out:
#               #name  latitude longitude country code population      country  \
# 20274  San Salvador  13.68935 -89.18718           SV     525990  El Salvador
# 20267     Soyapango  13.71024 -89.13989           SV     329708  El Salvador
# 20273     Santa Ana  13.99417 -89.55972           SV     176661  El Salvador
# 20276    San Miguel  13.48333 -88.18333           SV     161880  El Salvador
# 20284     Mejicanos  13.72397   -89.188           SV     160317  El Salvador
#
#       location_type
# 20274          camp
# 20267          camp
# 20273          camp
# 20276          camp
# 20284          camp

# %%
conflicts = locations[locations["location_type"]=="conflict_zone"]

# set camps to crossing data or if you want to use largest cities use commented out code 
# camps = locations[locations["location_type"]=="camp"]

camps=array_of_crossings_df

# %%
attractions = border_countries_results.copy()

# %%
attractions
# Out:
#        country  conflict historic_pop  historic_GDP_norm v2x_libdem  \
# 0  El Salvador  Honduras      6486201           0.184928       0.37
# 1    Guatemala  Honduras     16858333           1.000000      0.394
# 2    Nicaragua  Honduras      6624554           0.000000      0.058
#
#   predicted_shares country_code
# 0         0.192316           SV
# 1         0.393016           GT
# 2         0.023352           NI

# %%
camps
# Out:
#        country       crossing_name  longitude   latitude
# 0    Guatemala             Corinto -88.372008  15.595600
# 1    Guatemala       Aldea Caparja -89.226200  14.857400
# 2    Guatemala     Aguas Calientes -89.283170  14.531062
# 3  El Salvador              Citala -89.209463  14.371879
# 4  El Salvador          El Amatilo -87.773412  13.591830
# 5    Nicaragua    Aduana El Espino -86.724237  13.445553
# 6    Nicaragua  Frontera Las Manos -86.570047  13.792918

# %%
def get_closest(loc_lat, loc_lon, targets, mode):
    chunk_size = 25
    list_targets = [targets[i:i+chunk_size] for i in range(0,targets.shape[0],chunk_size)]
    output = None
    closest_seconds = 100000000000
    closest_loc = None
    for i in list_targets:
        results = gmaps.distance_matrix(origins=[(loc_lat, loc_lon)],
                                        destinations=list(tuple(zip(i.latitude, i.longitude))), mode=mode)
        for idx, val in enumerate(results["rows"][0]["elements"]):
            if val["status"] == "ZERO_RESULTS":
                continue
            attraction = attractions[attractions["country"] == i.iloc[idx]["country"]].predicted_shares.iloc[0]
            seconds = val["duration"]["value"]*(1/math.sqrt(attraction))
            if seconds <= closest_seconds:
                closest_seconds = seconds
                closest_loc = i.iloc[idx]
                output = val
    return closest_loc, output

# %% [markdown]
# Get conflict exit routes from each conflict city to the closest haven city.

# %%
conflict_exit_routes = {}
NoneType = type(None)
for kk, conflict in conflicts.iterrows():

    closest_crossing, crossing_val = get_closest(conflict.latitude, conflict.longitude, camps, flight_mode)
    if isinstance(closest_crossing, type(None)):
        print(f'{conflict["#name"]} No routes found')
    conflict_exit_routes[conflict["#name"]] = dict(crossing=closest_crossing, 
                                                   crossing_v=crossing_val)

for kk, vv in conflict_exit_routes.items():
    if not isinstance(vv['crossing'], type(None)):
        vv['crossing'] = dict(vv['crossing'])

with open(f'outputs/{conflict_country}_exit_routes_{flight_mode}.json','w') as f:
    f.write(json.dumps(conflict_exit_routes, cls=NpEncoder))

# %% [markdown]
#  Directions and Plotting.
#  Calculate all directions from each conflict city to each haven city

# %%
all_directions = {}
for kk, conflict in conflicts.iterrows():
    conflict_name = conflict['#name']
    print(f"Getting directions for conflict: {conflict_name}")

    if conflict_name in conflict_exit_routes:
        try:
            xing = conflict_exit_routes[conflict_name]['crossing']
            try:
                directions_result = gmaps.directions((conflict.latitude, conflict.longitude),
                                                 (xing['latitude'], xing['longitude']),
                                                 mode=flight_mode)
                directions_result[0]['name']=xing['crossing_name']
                directions_result[0]['country']=xing['country']
            except Exception as e:
                print(e)
                directions_result = None
            all_directions[conflict_name] = directions_result
        except Exception as e:
            print(e)
# Out:
# Getting directions for conflict: Tegucigalpa
# Getting directions for conflict: San Pedro Sula
# Getting directions for conflict: Choloma
# Getting directions for conflict: La Ceiba
# Getting directions for conflict: El Progreso
# Getting directions for conflict: Ciudad Choluteca
# Getting directions for conflict: Comayagua
# Getting directions for conflict: Puerto Cortez
# Getting directions for conflict: La Lima
# Getting directions for conflict: Danlí
# Getting directions for conflict: Siguatepeque
# Getting directions for conflict: Juticalpa
# Getting directions for conflict: Villanueva
# Getting directions for conflict: Tocoa
# Getting directions for conflict: Tela
# Getting directions for conflict: Santa Rosa de Copán
# Getting directions for conflict: Olanchito
# Getting directions for conflict: San Lorenzo
# Getting directions for conflict: Cofradía
# Getting directions for conflict: El Paraíso

# %%
with open(f'outputs/{conflict_country}_border_crossing_directions_{flight_mode}.json','w') as f:
    f.write(json.dumps(all_directions))

# %% [markdown]
# ## 6. Mapping

# %% [markdown]
# Calculate population percentiles of conflict cities and assign them a stroke value

# %%
locations=pd.read_csv(f'inputs/{conflict_country}_{flight_mode}_locations.csv')

# %%
conflicts = locations[locations["location_type"]=="conflict_zone"]

# %%
c_desc = conflicts.population.describe()

# %%
def bucket_population(population):
    if population <= c_desc['25%']:
        stroke = 2.5
    elif population <= c_desc['50%']:
        stroke = 5
    elif population <= c_desc['75%']:
        stroke = 7.5
    else:
        stroke = 10
    return stroke

# %%
conflicts['stroke'] = conflicts['population'].apply(lambda x: bucket_population(x))
# Out:
# <ipython-input-832-207bcbb2aaf0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   conflicts['stroke'] = conflicts['population'].apply(lambda x: bucket_population(x))

# %%
# Create Map
map = folium.Map(location=[conflicts.latitude.mean(),conflicts.longitude.mean()], zoom_start=6)

# Plot conflict starting points
for kk, start in conflicts.iterrows():
    start_m = folium.Marker([start.latitude, start.longitude], popup=start['#name'], 
                            icon=folium.Icon(icon='glyphicon glyphicon-fire', color='darkred'))
    start_m.add_to(map)
    
# Plot ending locations
for kk, vv in camps.iterrows():
    icon = 'glyphicon glyphicon-flag'
    color = 'orange'
    popup_text = f"<b>City Name: </b>{vv['crossing_name']}<br>"\
                 f"<b>Country: </b>{vv['country']}"
    popup = folium.Popup(popup_text, max_width=300,min_width=150)
    xing = folium.Marker([vv.latitude, vv.longitude], popup=popup, 
                          icon=folium.Icon(icon=icon, color=color))
    xing.add_to(map)

# plot exit routes (driving)
if "driving" in flight_mode:
    fg_d = folium.FeatureGroup("Driving")
    for kk, vv in all_directions.items():
        stroke = int(conflicts[conflicts['#name']==kk]['stroke'])
        population = "{:,}".format(int(conflicts[conflicts['#name']==kk]['population']))
        directions = all_directions[kk]
        if not isinstance(directions, type(None)):
            distance = directions[0]['legs'][0]['distance']['text']
            duration = directions[0]['legs'][0]['duration']['text']
            end_location = directions[0]['name']
            end_country = camps[camps['crossing_name']==end_location].country.values[0]
            tooltip = f"Travel between <b>{kk}</b> and <b>{end_location}, {end_country}</b> by car is <b>"\
                      f"{distance}</b> and takes <b>{duration}</b>.</br></br>"\
                      f"<b>{population}</b> people are effected by this conflict."
            polyline_ = polyline.decode(directions[0]['overview_polyline']['points'])
            polyline_m = folium.PolyLine(polyline_, color='#4A89F3', tooltip=tooltip, weight=stroke)
            polyline_m.add_to(fg_d)
    fg_d.add_to(map)
        
# plot exit routes (transit)
if "transit" in flight_mode:
    fg_t = folium.FeatureGroup("Transit")
    for kk, vv in all_directions.items():
        stroke = int(conflicts[conflicts['#name']==kk]['stroke'])
        population = "{:,}".format(int(conflicts[conflicts['#name']==kk]['population']))
        directions = all_directions[kk]
        if not isinstance(directions, type(None)):
            if len(directions) > 0:
                distance = directions[0]['legs'][0]['distance']['text']
                duration = directions[0]['legs'][0]['duration']['text']
                end_location = directions[0]['name']
                end_country = camps[camps['crossing_name']==end_location].country.values[0]
                tooltip = f"Travel between <b>{kk}</b> and <b>{end_location}, {end_country}</b> by transit is <b>"\
                          f"{distance}</b> and takes <b>{duration}</b>.</br></br>"\
                          f"<b>{population}</b> people are effected by this conflict."
                polyline_ = polyline.decode(directions[0]['overview_polyline']['points'])
                polyline_m = folium.PolyLine(polyline_, color='#7570b3', tooltip=tooltip, weight=stroke)
                polyline_m.add_to(fg_t)        
        

    fg_t.add_to(map)
# folium.Choropleth(
#     manual_routes,
#     line_weight=3,
#     line_color='#f03b20',
#     name='Manually generated routes'
# ).add_to(map)
        
# Add custom basemaps
basemaps['Google Satellite Hybrid'].add_to(map)
# basemaps['Esri Satellite'].add_to(map)
# basemaps['Google Satellite'].add_to(map)
basemaps['Google Maps'].add_to(map)

# Add a layer control panel to the map.
map.add_child(folium.LayerControl())

# Add fullscreen button
plugins.Fullscreen().add_to(map)

# %%
def add_legend(map):
    legend_html = """
    <style>
    @import url('https://fonts.googleapis.com/css2?family=Roboto:wght@100;300;400&display=swap');
    </style>
    
     <div style="
     padding-left:5px; padding-top:5px;
     position: fixed; 
     bottom: 50px; left: 50px; width: 160px; height: 120px;   
     border:2px solid grey; z-index:9999; border-radius: 15px;
     
     background-color:white;
     opacity: .85;
     
     font-size:14px;
     font-weight: bold;
     font-family: 'Roboto', sans-serif;
     ">

     <div class="awesome-marker-icon-darkred awesome-marker" style="margin-top: 10px; margin-left:5px;">
         <i class="fa-rotate-0 glyphicon glyphicon-glyphicon glyphicon-fire icon-white"></i>
     </div>
     <div style="margin-left:40px; margin-top:20px">Conflict Area</div>
     
     <div class="awesome-marker-icon-orange awesome-marker" style="margin-top: 60px; margin-left:5px;">
         <i class="fa-rotate-0 glyphicon glyphicon-glyphicon glyphicon-flag icon-white"></i>
     </div>
     <div style="margin-left:40px; margin-top:25px">Destination City</div>     
     
     
      </div> """.format( title = "Legend html")
    map.get_root().html.add_child(folium.Element( legend_html ))
    return map

# %%
map = add_legend(map)

# %%
display(map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_58e3760154204732a3bfd6bdadee0a20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.css%22/%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%40import%20url%28%27https%3A//fonts.googleapis.com/css2%3Ffamily%3DRoboto%3Awght%40100%3B300%3B400%26display%3Dswap%27%29%3B%0A%20%20%20%20%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%3Cdiv%20style%3D%22%0A%20%20%20%20%20padding-left%3A5px%3B%20padding-top%3A5px%3B%0A%20%20%20%20%20p ...

# %%
# save map
map.save(f'maps/{conflict_country}_{flight_mode}_Map.html')

# %%
conflicts['#name'].unique()
# Out:
# array(['Tegucigalpa', 'San Pedro Sula', 'Choloma', 'La Ceiba',
#        'El Progreso', 'Ciudad Choluteca', 'Comayagua', 'Puerto Cortez',
#        'La Lima', 'Danlí', 'Siguatepeque', 'Juticalpa', 'Villanueva',
#        'Tocoa', 'Tela', 'Santa Rosa de Copán', 'Olanchito', 'San Lorenzo',
#        'Cofradía', 'El Paraíso'], dtype=object)

# %% [markdown]
# ## 7. Recipient Country Refugee Counts

# %%
locations.head(50)
# Out:
#                     #name  latitude  longitude country code  population  \
# 0            San Salvador  13.68935  -89.18718           SV      525990
# 1               Soyapango  13.71024  -89.13989           SV      329708
# 2               Santa Ana  13.99417  -89.55972           SV      176661
# 3              San Miguel  13.48333  -88.18333           SV      161880
# 4               Mejicanos  13.72397  -89.18800           SV      160317
# 5             Santa Tecla  13.67694  -89.27972           SV      124694
# 6                   Apopa  13.80722  -89.17917           SV      112158
# 7                 Delgado  13.72171  -89.16874           SV       71594
# 8               Sonsonate  13.71889  -89.72417           SV       59468
# 9              San Marcos  13.66108  -89.18252           SV       54615
# 10         Guatemala City  14.64072  -90.51327           GT      994938
# 11                  Mixco  14.63077  -90.60711           GT      473080
# 12            Villa Nueva  14.52512  -90.58544           GT      406830
# 13                 Petapa  14.50189  -90.56196           GT      141455
# 14  San Juan Sacatepéquez  14.71889  -90.64417           GT      136886
# 15         Quetzaltenango  14.83472  -91.51806           GT      132230
# 16          Villa Canales  14.48285  -90.53425           GT      122194
# 17              Escuintla  14.30090  -90.78581           GT      103165
# 18              Chinautla  14.70289  -90.49983           GT       97172
# 19          Chimaltenango  14.66111  -90.81944           GT       82370
# 20                Managua  12.13282  -86.25040           NI      973087
# 21                   León  12.43787  -86.87804           NI      144538
# 22                 Masaya  11.97444  -86.09417           NI      130113
# 23             Chinandega  12.62937  -87.13105           NI      126387
# 24              Matagalpa  12.92559  -85.91747           NI      109089
# 25                 Estelí  13.09185  -86.35384           NI       96422
# 26                Granada  11.92988  -85.95602           NI       89409
# 27               Jinotega  13.09103  -86.00234           NI       55000
# 28               El Viejo  12.66348  -87.16663           NI       53504
# 29           Nueva Guinea  11.68758  -84.45616           NI       52929
# 30            Tegucigalpa  14.08180  -87.20681           HN      850848
# 31         San Pedro Sula  15.50417  -88.02500           HN      489466
# 32                Choloma  15.61444  -87.95302           HN      139100
# 33               La Ceiba  15.75971  -86.78221           HN      130218
# 34            El Progreso  15.40000  -87.80000           HN      100810
# 35       Ciudad Choluteca  13.30028  -87.19083           HN       75872
# 36              Comayagua  14.45139  -87.63750           HN       58784
# 37          Puerto Cortez  15.82562  -87.92968           HN       48013
# 38                La Lima  15.43333  -87.91667           HN       45955
# 39                  Danlí  14.03333  -86.58333           HN       44799
# 40           Siguatepeque  14.59691  -87.83102           HN       43141
# 41              Juticalpa  14.66667  -86.21944           HN       33686
# 42             Villanueva  15.31476  -87.99383           HN       31571
# 43                  Tocoa  15.68333  -86.00000           HN       30785
# 44                   Tela  15.77425  -87.46731           HN       29325
# 45    Santa Rosa de Copán  14.76667  -88.77917           HN       27753
# 46              Olanchito  15.48131  -86.57415           HN       25969
# 47            San Lorenzo  13.42417  -87.44722           HN       22289
# 48               Cofradía  15.40000  -88.15000           HN       20353
# 49             El Paraíso  13.86667  -86.55000           HN       18779
#
#         country  location_type
# 0   El Salvador           camp
# 1   El Salvador           camp
# 2   El Salvador           camp
# 3   El Salvador           camp
# 4   El Salvador           camp
# 5   El Salvador           camp
# 6   El Salvador           camp
# 7   El Salvador           camp
# 8   El Salvador           camp
# 9   El Salvador           camp
# 10    Guatemala           camp
# 11    Guatemala           camp
# 12    Guatemala           camp
# 13    Guatemala           camp
# 14    Guatemala           camp
# 15    Guatemala           camp
# 16    Guatemala           camp
# 17    Guatemala           camp
# 18    Guatemala           camp
# 19    Guatemala           camp
# 20    Nicaragua           camp
# 21    Nicaragua           camp
# 22    Nicaragua           camp
# 23    Nicaragua           camp
# 24    Nicaragua           camp
# 25    Nicaragua           camp
# 26    Nicaragua           camp
# 27    Nicaragua           camp
# 28    Nicaragua           camp
# 29    Nicaragua           camp
# 30     Honduras  conflict_zone
# 31     Honduras  conflict_zone
# 32     Honduras  conflict_zone
# 33     Honduras  conflict_zone
# 34     Honduras  conflict_zone
# 35     Honduras  conflict_zone
# 36     Honduras  conflict_zone
# 37     Honduras  conflict_zone
# 38     Honduras  conflict_zone
# 39     Honduras  conflict_zone
# 40     Honduras  conflict_zone
# 41     Honduras  conflict_zone
# 42     Honduras  conflict_zone
# 43     Honduras  conflict_zone
# 44     Honduras  conflict_zone
# 45     Honduras  conflict_zone
# 46     Honduras  conflict_zone
# 47     Honduras  conflict_zone
# 48     Honduras  conflict_zone
# 49     Honduras  conflict_zone

# %%
conflicts = locations[locations['location_type']=='conflict_zone']
#camps = locations[locations['location_type']=='camp']

# %%
conflicts
# Out:
#                   #name  latitude  longitude country code  population  \
# 30          Tegucigalpa  14.08180  -87.20681           HN      850848
# 31       San Pedro Sula  15.50417  -88.02500           HN      489466
# 32              Choloma  15.61444  -87.95302           HN      139100
# 33             La Ceiba  15.75971  -86.78221           HN      130218
# 34          El Progreso  15.40000  -87.80000           HN      100810
# 35     Ciudad Choluteca  13.30028  -87.19083           HN       75872
# 36            Comayagua  14.45139  -87.63750           HN       58784
# 37        Puerto Cortez  15.82562  -87.92968           HN       48013
# 38              La Lima  15.43333  -87.91667           HN       45955
# 39                Danlí  14.03333  -86.58333           HN       44799
# 40         Siguatepeque  14.59691  -87.83102           HN       43141
# 41            Juticalpa  14.66667  -86.21944           HN       33686
# 42           Villanueva  15.31476  -87.99383           HN       31571
# 43                Tocoa  15.68333  -86.00000           HN       30785
# 44                 Tela  15.77425  -87.46731           HN       29325
# 45  Santa Rosa de Copán  14.76667  -88.77917           HN       27753
# 46            Olanchito  15.48131  -86.57415           HN       25969
# 47          San Lorenzo  13.42417  -87.44722           HN       22289
# 48             Cofradía  15.40000  -88.15000           HN       20353
# 49           El Paraíso  13.86667  -86.55000           HN       18779
#
#      country  location_type
# 30  Honduras  conflict_zone
# 31  Honduras  conflict_zone
# 32  Honduras  conflict_zone
# 33  Honduras  conflict_zone
# 34  Honduras  conflict_zone
# 35  Honduras  conflict_zone
# 36  Honduras  conflict_zone
# 37  Honduras  conflict_zone
# 38  Honduras  conflict_zone
# 39  Honduras  conflict_zone
# 40  Honduras  conflict_zone
# 41  Honduras  conflict_zone
# 42  Honduras  conflict_zone
# 43  Honduras  conflict_zone
# 44  Honduras  conflict_zone
# 45  Honduras  conflict_zone
# 46  Honduras  conflict_zone
# 47  Honduras  conflict_zone
# 48  Honduras  conflict_zone
# 49  Honduras  conflict_zone

# %%
conflict_exit_routes['Tegucigalpa']['crossing']
# Out:
# {'country': 'El Salvador',
#  'crossing_name': 'El Amatilo',
#  'longitude': -87.773412,
#  'latitude': 13.59183}

# %% [markdown]
# Use routes gerated above called conflict_exit_routes

# %%
def get_exit_route(row, mode):
    try:
        print(row)
        dest = conflict_exit_routes[row['#name']]['crossing']['crossing_name']
        dest = camps[camps['crossing_name']==dest].country.values[0]
    except:
        dest = None
    row[f'{mode}_destination'] = dest
    return row

# %%
def get_exit_city(row, mode):
    try:
        dest = conflict_exit_routes[row['#name']]['crossing']['crossing_name']
    except:
        dest = None
    row[f'{mode}_destination_city'] = dest
    return row

# %%
conflicts = conflicts.apply(lambda row: get_exit_route(row, flight_mode), axis=1)

conflicts = conflicts.apply(lambda row: get_exit_city(row, flight_mode), axis=1)
# Out:
# #name              Tegucigalpa
# latitude               14.0818
# longitude            -87.20681
# country code                HN
# population              850848
# country               Honduras
# location_type    conflict_zone
# Name: 30, dtype: object
# #name            San Pedro Sula
# latitude               15.50417
# longitude               -88.025
# country code                 HN
# population               489466
# country                Honduras
# location_type     conflict_zone
# Name: 31, dtype: object
# #name                  Choloma
# latitude              15.61444
# longitude            -87.95302
# country code                HN
# population              139100
# country               Honduras
# location_type    conflict_zone
# Name: 32, dtype: object
# #name                 La Ceiba
# latitude              15.75971
# longitude            -86.78221
# country code                HN
# population              130218
# country               Honduras
# location_type    conflict_zone
# Name: 33, dtype: object
# #name              El Progreso
# latitude                  15.4
# longitude                -87.8
# country code                HN
# population              100810
# country               Honduras
# location_type    conflict_zone
# Name: 34, dtype: object
# #name            Ciudad Choluteca
# latitude                 13.30028
# longitude               -87.19083
# country code                   HN
# population                  75872
# country                  Honduras
# location_type       conflict_zone
# Name: 35, dtype: object
# #name                Comayagua
# latitude              14.45139
# longitude             -87.6375
# country code                HN
# population               58784
# country               Honduras
# location_type    conflict_zone
# Name: 36, dtype: object
# #name            Puerto Cortez
# latitude              15.82562
# longitude            -87.92968
# country code                HN
# population               48013
# country               Honduras
# location_type    conflict_zone
# Name: 37, dtype: object
# #name                  La Lima
# latitude              15.43333
# longitude            -87.91667
# country code                HN
# population               45955
# country               Honduras
# location_type    conflict_zone
# Name: 38, dtype: object
# #name                    Danlí
# latitude              14.03333
# longitude            -86.58333
# country code                HN
# population               44799
# country               Honduras
# location_type    conflict_zone
# Name: 39, dtype: object
# #name             Siguatepeque
# latitude              14.59691
# longitude            -87.83102
# country code                HN
# population               43141
# country               Honduras
# location_type    conflict_zone
# Name: 40, dtype: object
# #name                Juticalpa
# latitude              14.66667
# longitude            -86.21944
# country code                HN
# population               33686
# country               Honduras
# location_type    conflict_zone
# Name: 41, dtype: object
# #name               Villanueva
# latitude              15.31476
# longitude            -87.99383
# country code                HN
# population               31571
# country               Honduras
# location_type    conflict_zone
# Name: 42, dtype: object
# #name                    Tocoa
# latitude              15.68333
# longitude                -86.0
# country code                HN
# population               30785
# country               Honduras
# location_type    conflict_zone
# Name: 43, dtype: object
# #name                     Tela
# latitude              15.77425
# longitude            -87.46731
# country code                HN
# population               29325
# country               Honduras
# location_type    conflict_zone
# Name: 44, dtype: object
# #name            Santa Rosa de Copán
# latitude                    14.76667
# longitude                  -88.77917
# country code                      HN
# population                     27753
# country                     Honduras
# location_type          conflict_zone
# Name: 45, dtype: object
# #name                Olanchito
# latitude              15.48131
# longitude            -86.57415
# country code                HN
# population               25969
# country               Honduras
# location_type    conflict_zone
# Name: 46, dtype: object
# #name              San Lorenzo
# latitude              13.42417
# longitude            -87.44722
# country code                HN
# population               22289
# country               Honduras
# location_type    conflict_zone
# Name: 47, dtype: object
# #name                 Cofradía
# latitude                  15.4
# longitude               -88.15
# country code                HN
# population               20353
# country               Honduras
# location_type    conflict_zone
# Name: 48, dtype: object
# #name               El Paraíso
# latitude              13.86667
# longitude               -86.55
# country code                HN
# population               18779
# country               Honduras
# location_type    conflict_zone
# Name: 49, dtype: object

# %%
conflicts.groupby([f'{flight_mode}_destination']).country.count()
# Out:
# driving_destination
# El Salvador     6
# Guatemala      12
# Nicaragua       2
# Name: country, dtype: int64

# %%
border_countries=  border_countries_results.copy()

# %% [markdown]
# First sum the total population across twenty conflicts. Then get the percentage of total people in conflict zones at each conflict.For example if the total population of the 20 conflict zones is 1 million people and conflict zone A has a population of 200,000 people. Then it has 20% of people in conflict. If the total country population is 5 million, and 10% are expected to flee due to the conflict then we "route" 10% * 20% * 5,000,000 = 100,000 people through conflict zone A.

# %%
#total population of conflict country. Times the percent we want to leave due to conflict
conflict_country_historic_pop=int(conflict_country_historic_pop)
conflicts["pop_percent_of_conflict_cities"]=conflicts["population"]/conflicts["population"].sum()
conflicts[f"refugee_estimated_leaving_via_{flight_mode}"]=conflicts["pop_percent_of_conflict_cities"]*(conflict_country_historic_pop*percent_of_pop_leaving)

# %%
conflicts
# Out:
#                   #name  latitude  longitude country code  population  \
# 30          Tegucigalpa  14.08180  -87.20681           HN      850848
# 31       San Pedro Sula  15.50417  -88.02500           HN      489466
# 32              Choloma  15.61444  -87.95302           HN      139100
# 33             La Ceiba  15.75971  -86.78221           HN      130218
# 34          El Progreso  15.40000  -87.80000           HN      100810
# 35     Ciudad Choluteca  13.30028  -87.19083           HN       75872
# 36            Comayagua  14.45139  -87.63750           HN       58784
# 37        Puerto Cortez  15.82562  -87.92968           HN       48013
# 38              La Lima  15.43333  -87.91667           HN       45955
# 39                Danlí  14.03333  -86.58333           HN       44799
# 40         Siguatepeque  14.59691  -87.83102           HN       43141
# 41            Juticalpa  14.66667  -86.21944           HN       33686
# 42           Villanueva  15.31476  -87.99383           HN       31571
# 43                Tocoa  15.68333  -86.00000           HN       30785
# 44                 Tela  15.77425  -87.46731           HN       29325
# 45  Santa Rosa de Copán  14.76667  -88.77917           HN       27753
# 46            Olanchito  15.48131  -86.57415           HN       25969
# 47          San Lorenzo  13.42417  -87.44722           HN       22289
# 48             Cofradía  15.40000  -88.15000           HN       20353
# 49           El Paraíso  13.86667  -86.55000           HN       18779
#
#      country  location_type driving_destination driving_destination_city  \
# 30  Honduras  conflict_zone         El Salvador               El Amatilo
# 31  Honduras  conflict_zone           Guatemala                  Corinto
# 32  Honduras  conflict_zone           Guatemala                  Corinto
# 33  Honduras  conflict_zone           Guatemala                  Corinto
# 34  Honduras  conflict_zone           Guatemala                  Corinto
# 35  Honduras  conflict_zone         El Salvador               El Amatilo
# 36  Honduras  conflict_zone         El Salvador               El Amatilo
# 37  Honduras  conflict_zone           Guatemala                  Corinto
# 38  Honduras  conflict_zone           Guatemala                  Corinto
# 39  Honduras  conflict_zone           Nicaragua       Frontera Las Manos
# 40  Honduras  conflict_zone         El Salvador               El Amatilo
# 41  Honduras  conflict_zone         El Salvador               El Amatilo
# 42  Honduras  conflict_zone           Guatemala                  Corinto
# 43  Honduras  conflict_zone           Guatemala                  Corinto
# 44  Honduras  conflict_zone           Guatemala                  Corinto
# 45  Honduras  conflict_zone           Guatemala            Aldea Caparja
# 46  Honduras  conflict_zone           Guatemala                  Corinto
# 47  Honduras  conflict_zone         El Salvador               El Amatilo
# 48  Honduras  conflict_zone           Guatemala                  Corinto
# 49  Honduras  conflict_zone           Nicaragua       Frontera Las Manos
#
#     pop_percent_of_conflict_cities  refugee_estimated_leaving_via_driving
# 30                        0.375234                          371654.087891
# 31                        0.215860                          213800.866646
# 32                        0.061345                           60759.481865
# 33                        0.057428                           56879.785834
# 34                        0.044458                           44034.244190
# 35                        0.033460                           33141.217887
# 36                        0.025924                           25677.105550
# 37                        0.021174                           20972.286145
# 38                        0.020267                           20073.342840
# 39                        0.019757                           19568.397039
# 40                        0.019026                           18844.175465
# 41                        0.014856                           14714.190554
# 42                        0.013923                           13790.349403
# 43                        0.013577                           13447.021202
# 44                        0.012933                           12809.286885
# 45                        0.012239                           12122.630483
# 46                        0.011453                           11343.371564
# 47                        0.009830                            9735.931641
# 48                        0.008976                            8890.278464
# 49                        0.008282                            8202.748454

# %%
conflicts[f'refugee_estimated_leaving_via_{flight_mode}'].sum()
# Out:
# 990460.8000000002

# %%
COL=["#name","country",f"{flight_mode}_destination",f'{flight_mode}_destination_city',f"refugee_estimated_leaving_via_{flight_mode}"]

# %%
reduced_conflicts=conflicts[COL]

# %%
reduced_conflicts=reduced_conflicts.rename(columns={"#name":"origin city", "country":"origin country",f"{flight_mode}_destination":"destination country",f"{flight_mode}_destination_city":"destination city",f"refugee_estimated_leaving_via_{flight_mode}":"total refugees"})

# %%
reduced_conflicts.to_csv(f'outputs/{conflict_country}_{flight_mode}_total_refugees.csv',index=False)

# %%
reduced_conflicts
# Out:
#             origin city origin country destination country  \
# 30          Tegucigalpa       Honduras         El Salvador
# 31       San Pedro Sula       Honduras           Guatemala
# 32              Choloma       Honduras           Guatemala
# 33             La Ceiba       Honduras           Guatemala
# 34          El Progreso       Honduras           Guatemala
# 35     Ciudad Choluteca       Honduras         El Salvador
# 36            Comayagua       Honduras         El Salvador
# 37        Puerto Cortez       Honduras           Guatemala
# 38              La Lima       Honduras           Guatemala
# 39                Danlí       Honduras           Nicaragua
# 40         Siguatepeque       Honduras         El Salvador
# 41            Juticalpa       Honduras         El Salvador
# 42           Villanueva       Honduras           Guatemala
# 43                Tocoa       Honduras           Guatemala
# 44                 Tela       Honduras           Guatemala
# 45  Santa Rosa de Copán       Honduras           Guatemala
# 46            Olanchito       Honduras           Guatemala
# 47          San Lorenzo       Honduras         El Salvador
# 48             Cofradía       Honduras           Guatemala
# 49           El Paraíso       Honduras           Nicaragua
#
#       destination city  total refugees
# 30          El Amatilo   371654.087891
# 31             Corinto   213800.866646
# 32             Corinto    60759.481865
# 33             Corinto    56879.785834
# 34             Corinto    44034.244190
# 35          El Amatilo    33141.217887
# 36          El Amatilo    25677.105550
# 37             Corinto    20972.286145
# 38             Corinto    20073.342840
# 39  Frontera Las Manos    19568.397039
# 40          El Amatilo    18844.175465
# 41          El Amatilo    14714.190554
# 42             Corinto    13790.349403
# 43             Corinto    13447.021202
# 44             Corinto    12809.286885
# 45       Aldea Caparja    12122.630483
# 46             Corinto    11343.371564
# 47          El Amatilo     9735.931641
# 48             Corinto     8890.278464
# 49  Frontera Las Manos     8202.748454

# %% [markdown]
# Summarize for country level numbers

# %%
country_level_refugee=pd.DataFrame(data=reduced_conflicts.groupby(['destination country'])["total refugees"].sum())

# %%
country_level_refugee['total refugees']=country_level_refugee["total refugees"].round()

# %%
country_level_refugee
# Out:
#                      total refugees
# destination country
# El Salvador                473767.0
# Guatemala                  488923.0
# Nicaragua                   27771.0
